# %%
import tensorflow as tf
import os
import gzip
import matplotlib.pyplot as plt
import numpy as np
import _pickle as cPickle
plt.ion()

# %% [markdown]
# Data Loading

# %%
#loading data
def mnist(datasets_dir='./data'):
    if not os.path.exists(datasets_dir):
        os.mkdir(datasets_dir)
    data_file = os.path.join(datasets_dir, 'mnist.pkl.gz')
    if not os.path.exists(data_file):
        print('... downloading MNIST from the web')
        try:
            import urllib
            urllib.urlretrieve('http://google.com')
        except AttributeError:
            import urllib.request as urllib
        url = 'http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz'
        urllib.urlretrieve(url, data_file)

    print('... loading data')
    # Load the dataset
    f = gzip.open(data_file, 'rb')
    try:
        train_set, valid_set, test_set = cPickle.load(f, encoding="latin1")
    except TypeError:
        train_set, valid_set, test_set = cPickle.load(f)
    f.close()

    test_x, test_y = test_set
    test_x = test_x.astype('float32')
    test_x = test_x.astype('float32').reshape(test_x.shape[0], 1, 28, 28)
    test_y = test_y.astype('int32')
    valid_x, valid_y = valid_set
    valid_x = valid_x.astype('float32')
    valid_x = valid_x.astype('float32').reshape(valid_x.shape[0], 1, 28, 28)
    valid_y = valid_y.astype('int32')
    train_x, train_y = train_set
    train_x = train_x.astype('float32').reshape(train_x.shape[0], 1, 28, 28)
    train_y = train_y.astype('int32')
    rval = [(train_x, train_y), (valid_x, valid_y), (test_x, test_y)]
    print('... done loading data')
    return rval

# %%
#separating data into trainining, validation and test dataset
Dtrain, Dval, Dtest = mnist()
X_train, y_train = Dtrain
X_valid, y_valid = Dval

n_train_samples = X_train.shape[0]
train_idxs = np.random.permutation(X_train.shape[0])[:n_train_samples]
X_train = X_train[train_idxs]
y_train = y_train[train_idxs]
# Out:
# ... loading data
# ... done loading data

# %%
"""
SKELETON
def model_fn(features, labels, mode, params):
   # Logic to do the following:
   # 1. Configure the model via TensorFlow operations
   # 2. Define the loss function for training/evaluation
   # 3. Define the training operation/optimizer
   # 4. Generate predictions
   # 5. Return predictions/loss/train_op/eval_metric_ops in EstimatorSpec object
   return EstimatorSpec(mode, predictions, loss, train_op, eval_metric_ops)
"""

def cnn(features, labels, mode, params):
    
    num_filters, learning_rate = params["num_filters"], params["learning_rate"]
    
    #1. network architecture
    # Input Layer
    inputs = tf.reshape(features["x"], [-1, 28, 28, 1])

    # 1st layer
    cl_1 = tf.layers.conv2d(inputs, filters=num_filters, kernel_size=[3, 3], padding="same", activation=tf.nn.relu)
    pool_cl1 = tf.layers.max_pooling2d(inputs=cl_1, pool_size=[2, 2], strides=1)

    # 2nd layer
    cl_2 = tf.layers.conv2d(pool_cl1, filters=num_filters, kernel_size=[3, 3], padding="same", activation=tf.nn.relu)
    pool_cl2 = tf.layers.max_pooling2d(cl_2, pool_size=[2, 2], strides=1)

    # fully connected
    pool_cl2_flat = tf.reshape(pool_cl2, [-1, 26 * 26 * num_filters])
    dense = tf.layers.dense(pool_cl2_flat, units=128)
    dropout = tf.layers.dropout(dense, rate=0.5) 
    
    # output layer
    output = tf.layers.dense(inputs=dropout, units=10)
    
    
    #2. calculate losses cross entropy with sgd for training and evaluation
    onehot_y = tf.one_hot(indices=tf.cast(labels, tf.int32), depth=10)
    cross_entropy_loss = tf.losses.softmax_cross_entropy(onehot_labels=onehot_y, logits=output)
    
    #3. define the training operation/optimizer
    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.train.GradientDescentOptimizer(learning_rate)
        train_step = optimizer.minimize(loss=cross_entropy_loss, global_step=tf.train.get_global_step())    
        return tf.estimator.EstimatorSpec(mode=mode, loss=cross_entropy_loss, train_op=train_step)
    
    #4. generate predictions
    predictions = tf.argmax(input=output, axis=1)
    """"
    predictions = {
    "classes": tf.argmax(input=output, axis=1),
    "probabilities": tf.nn.softmax(output, name="softmax_tensor")}"""

    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)
        
    eval_metric_ops = {
        "accuracy": tf.metrics.accuracy(labels=labels, predictions=predictions)}
    specs = tf.estimator.EstimatorSpec(mode=mode, loss=cross_entropy_loss, eval_metric_ops=eval_metric_ops)
    return specs

# %%
filter_nums = [8, 16, 32, 64, 128, 256]
learning_rates = [0.1, 0.01, 0.001, 0.0001]
default_filter = 16
default_rate = 0.01
max_epochs = 20
batch_size = 500

# %%
def train(X_train, y_train, X_valid, y_valid, learning_rate, batch_size, max_epochs, filter_nums):
    val_errs = np.zeros(max_epochs)
    #Initializing estimator
    mnist_model = tf.estimator.Estimator(cnn, params = {"num_filters": filter_nums, "learning_rate": learning_rate})
    #valid_loss = np.zeros(max_epochs)
    #data_storage =[]   
    for epoch in range(1, max_epochs+1):
        #training 
        train_input_fn = tf.estimator.inputs.numpy_input_fn(
            x = {"x": X_train}, y = y_train,
            batch_size = batch_size, num_epochs = None, 
            shuffle = True)
        mnist_model.train(train_input_fn, steps = X_train.shape[0]/batch_size)

        #evaluation
        eval_input_fn = tf.estimator.inputs.numpy_input_fn(
            x = {"x": X_valid},y = y_valid,
            batch_size = batch_size,
            shuffle = False)
        evaluator = mnist_model.evaluate(eval_input_fn)
        val_errs[epoch-1] = 1.-evaluator['accuracy']
        print("Epoch: {}, Validation error: {:.4f}, Learning rate: {:.4f}".format(epoch, 1.-evaluator['accuracy'], learning_rate))
    return val_errs

# %%
import time

val_errs = np.zeros((len(learning_rates),max_epochs))
for idx,rate in enumerate(learning_rates):
    t0 = time.time()
    val_errs[idx] = train(X_train,y_train,X_valid,y_valid, rate, batch_size, max_epochs, default_filter)
    t1 = time.time()
    print('Duration: {:.1f}s'.format(t1-t0))
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Hakan\\AppData\\Local\\Temp\\tmp34_7jis8', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001CC01224D30>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 2.29072, step = 1
# INFO:tensorflow:Saving checkpoints for 100 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.428524.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:02:48
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-100
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:02:59
# INFO:tensorflow:Saving dict for global step 100: accuracy = 0.9023, global_step = 100, loss = 0.318656
# Epoch: 1, Validation error: 0.0977, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-100
# INFO:tensorflow:Saving checkpoints for 101 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.320599, step = 101
# INFO:tensorflow:Saving checkpoints for 200 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.173568.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:05:29
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-200
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:05:40
# INFO:tensorflow:Saving dict for global step 200: accuracy = 0.9615, global_step = 200, loss = 0.136161
# Epoch: 2, Validation error: 0.0385, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-200
# INFO:tensorflow:Saving checkpoints for 201 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.190225, step = 201
# INFO:tensorflow:Saving checkpoints for 300 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.177542.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:08:15
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-300
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:08:25
# INFO:tensorflow:Saving dict for global step 300: accuracy = 0.9461, global_step = 300, loss = 0.17635
# Epoch: 3, Validation error: 0.0539, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-300
# INFO:tensorflow:Saving checkpoints for 301 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.180397, step = 301
# INFO:tensorflow:Saving checkpoints for 400 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0931768.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:11:03
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-400
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:11:14
# INFO:tensorflow:Saving dict for global step 400: accuracy = 0.9707, global_step = 400, loss = 0.103589
# Epoch: 4, Validation error: 0.0293, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-400
# INFO:tensorflow:Saving checkpoints for 401 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.108998, step = 401
# INFO:tensorflow:Saving checkpoints for 500 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.09062.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:13:44
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-500
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:13:55
# INFO:tensorflow:Saving dict for global step 500: accuracy = 0.9716, global_step = 500, loss = 0.0992123
# Epoch: 5, Validation error: 0.0284, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-500
# INFO:tensorflow:Saving checkpoints for 501 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.0882665, step = 501
# INFO:tensorflow:Saving checkpoints for 600 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0786882.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:16:24
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-600
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:16:34
# INFO:tensorflow:Saving dict for global step 600: accuracy = 0.9785, global_step = 600, loss = 0.0829581
# Epoch: 6, Validation error: 0.0215, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-600
# INFO:tensorflow:Saving checkpoints for 601 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.118022, step = 601
# INFO:tensorflow:Saving checkpoints for 700 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0817914.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:19:01
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-700
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:19:12
# INFO:tensorflow:Saving dict for global step 700: accuracy = 0.978, global_step = 700, loss = 0.0768112
# Epoch: 7, Validation error: 0.0220, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-700
# INFO:tensorflow:Saving checkpoints for 701 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.0813535, step = 701
# INFO:tensorflow:Saving checkpoints for 800 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.112008.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:21:19
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-800
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:21:29
# INFO:tensorflow:Saving dict for global step 800: accuracy = 0.9749, global_step = 800, loss = 0.0843333
# Epoch: 8, Validation error: 0.0251, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-800
# INFO:tensorflow:Saving checkpoints for 801 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.128774, step = 801
# INFO:tensorflow:Saving checkpoints for 900 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.382684.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:23:35
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-900
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:23:44
# INFO:tensorflow:Saving dict for global step 900: accuracy = 0.9078, global_step = 900, loss = 0.298399
# Epoch: 9, Validation error: 0.0922, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-900
# INFO:tensorflow:Saving checkpoints for 901 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.267008, step = 901
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.068857.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:25:51
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:26:00
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.9763, global_step = 1000, loss = 0.0795304
# Epoch: 10, Validation error: 0.0237, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1000
# INFO:tensorflow:Saving checkpoints for 1001 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.0928415, step = 1001
# INFO:tensorflow:Saving checkpoints for 1100 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0536686.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:28:28
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1100
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:28:38
# INFO:tensorflow:Saving dict for global step 1100: accuracy = 0.9798, global_step = 1100, loss = 0.0685966
# Epoch: 11, Validation error: 0.0202, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1100
# INFO:tensorflow:Saving checkpoints for 1101 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.0732207, step = 1101
# INFO:tensorflow:Saving checkpoints for 1200 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0439114.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:30:46
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1200
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:30:55
# INFO:tensorflow:Saving dict for global step 1200: accuracy = 0.9818, global_step = 1200, loss = 0.0638926
# Epoch: 12, Validation error: 0.0182, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1200
# INFO:tensorflow:Saving checkpoints for 1201 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.0496216, step = 1201
# INFO:tensorflow:Saving checkpoints for 1300 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0360148.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:33:03
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1300
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:33:12
# INFO:tensorflow:Saving dict for global step 1300: accuracy = 0.9833, global_step = 1300, loss = 0.0613373
# Epoch: 13, Validation error: 0.0167, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1300
# INFO:tensorflow:Saving checkpoints for 1301 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.0477175, step = 1301
# INFO:tensorflow:Saving checkpoints for 1400 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0398931.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:35:44
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1400
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:35:54
# INFO:tensorflow:Saving dict for global step 1400: accuracy = 0.984, global_step = 1400, loss = 0.057778
# Epoch: 14, Validation error: 0.0160, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1400
# INFO:tensorflow:Saving checkpoints for 1401 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.0302664, step = 1401
# INFO:tensorflow:Saving checkpoints for 1500 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0327863.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:38:05
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1500
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:38:15
# INFO:tensorflow:Saving dict for global step 1500: accuracy = 0.9832, global_step = 1500, loss = 0.0574259
# Epoch: 15, Validation error: 0.0168, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1500
# INFO:tensorflow:Saving checkpoints for 1501 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.0207733, step = 1501
# INFO:tensorflow:Saving checkpoints for 1600 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0326481.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:40:24
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1600
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:40:34
# INFO:tensorflow:Saving dict for global step 1600: accuracy = 0.9836, global_step = 1600, loss = 0.0588457
# Epoch: 16, Validation error: 0.0164, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1600
# INFO:tensorflow:Saving checkpoints for 1601 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.0610627, step = 1601
# INFO:tensorflow:Saving checkpoints for 1700 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0410238.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:43:04
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1700
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:43:14
# INFO:tensorflow:Saving dict for global step 1700: accuracy = 0.983, global_step = 1700, loss = 0.0604779
# Epoch: 17, Validation error: 0.0170, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1700
# INFO:tensorflow:Saving checkpoints for 1701 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.0423359, step = 1701
# INFO:tensorflow:Saving checkpoints for 1800 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0424078.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:45:45
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1800
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:45:56
# INFO:tensorflow:Saving dict for global step 1800: accuracy = 0.9847, global_step = 1800, loss = 0.0554418
# Epoch: 18, Validation error: 0.0153, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1800
# INFO:tensorflow:Saving checkpoints for 1801 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.0449993, step = 1801
# INFO:tensorflow:Saving checkpoints for 1900 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0360918.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:48:09
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1900
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:48:19
# INFO:tensorflow:Saving dict for global step 1900: accuracy = 0.9842, global_step = 1900, loss = 0.0553101
# Epoch: 19, Validation error: 0.0158, Learning rate: 0.1000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-1900
# INFO:tensorflow:Saving checkpoints for 1901 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:loss = 0.0578713, step = 1901
# INFO:tensorflow:Saving checkpoints for 2000 into C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0359938.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:50:33
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmp34_7jis8\model.ckpt-2000
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:50:44
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 0.9831, global_step = 2000, loss = 0.0563891
# Epoch: 20, Validation error: 0.0169, Learning rate: 0.1000
# Duration: 3024.4s
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Hakan\\AppData\\Local\\Temp\\tmpvz46kow9', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001CC029F3208>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 2.30012, step = 1
# INFO:tensorflow:Saving checkpoints for 100 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.513265.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:53:29
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-100
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:53:39
# INFO:tensorflow:Saving dict for global step 100: accuracy = 0.8529, global_step = 100, loss = 0.4674
# Epoch: 1, Validation error: 0.1471, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-100
# INFO:tensorflow:Saving checkpoints for 101 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.502904, step = 101
# INFO:tensorflow:Saving checkpoints for 200 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.416239.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:56:10
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-200
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:56:20
# INFO:tensorflow:Saving dict for global step 200: accuracy = 0.8872, global_step = 200, loss = 0.371907
# Epoch: 2, Validation error: 0.1128, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-200
# INFO:tensorflow:Saving checkpoints for 201 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.357214, step = 201
# INFO:tensorflow:Saving checkpoints for 300 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.344545.
# INFO:tensorflow:Starting evaluation at 2017-11-21-22:58:33
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-300
# INFO:tensorflow:Finished evaluation at 2017-11-21-22:58:43
# INFO:tensorflow:Saving dict for global step 300: accuracy = 0.9061, global_step = 300, loss = 0.313017
# Epoch: 3, Validation error: 0.0939, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-300
# INFO:tensorflow:Saving checkpoints for 301 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.38014, step = 301
# INFO:tensorflow:Saving checkpoints for 400 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.283652.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:01:23
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-400
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:01:35
# INFO:tensorflow:Saving dict for global step 400: accuracy = 0.9137, global_step = 400, loss = 0.295304
# Epoch: 4, Validation error: 0.0863, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-400
# INFO:tensorflow:Saving checkpoints for 401 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.369752, step = 401
# INFO:tensorflow:Saving checkpoints for 500 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.334707.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:04:23
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-500
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:04:35
# INFO:tensorflow:Saving dict for global step 500: accuracy = 0.9081, global_step = 500, loss = 0.309437
# Epoch: 5, Validation error: 0.0919, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-500
# INFO:tensorflow:Saving checkpoints for 501 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.333958, step = 501
# INFO:tensorflow:Saving checkpoints for 600 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.361965.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:07:01
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-600
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:07:11
# INFO:tensorflow:Saving dict for global step 600: accuracy = 0.9074, global_step = 600, loss = 0.314066
# Epoch: 6, Validation error: 0.0926, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-600
# INFO:tensorflow:Saving checkpoints for 601 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.403916, step = 601
# INFO:tensorflow:Saving checkpoints for 700 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.244375.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:10:03
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-700
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:10:15
# INFO:tensorflow:Saving dict for global step 700: accuracy = 0.9289, global_step = 700, loss = 0.252168
# Epoch: 7, Validation error: 0.0711, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-700
# INFO:tensorflow:Saving checkpoints for 701 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.236372, step = 701
# INFO:tensorflow:Saving checkpoints for 800 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.251667.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:13:04
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-800
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:13:14
# INFO:tensorflow:Saving dict for global step 800: accuracy = 0.9259, global_step = 800, loss = 0.255221
# Epoch: 8, Validation error: 0.0741, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-800
# INFO:tensorflow:Saving checkpoints for 801 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.262075, step = 801
# INFO:tensorflow:Saving checkpoints for 900 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.285934.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:16:00
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-900
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:16:11
# INFO:tensorflow:Saving dict for global step 900: accuracy = 0.9315, global_step = 900, loss = 0.241227
# Epoch: 9, Validation error: 0.0685, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-900
# INFO:tensorflow:Saving checkpoints for 901 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.286976, step = 901
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.266588.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:18:47
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:18:57
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.9375, global_step = 1000, loss = 0.221226
# Epoch: 10, Validation error: 0.0625, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1000
# INFO:tensorflow:Saving checkpoints for 1001 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.224043, step = 1001
# INFO:tensorflow:Saving checkpoints for 1100 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.303797.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:21:23
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1100
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:21:33
# INFO:tensorflow:Saving dict for global step 1100: accuracy = 0.9361, global_step = 1100, loss = 0.221683
# Epoch: 11, Validation error: 0.0639, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1100
# INFO:tensorflow:Saving checkpoints for 1101 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.180411, step = 1101
# INFO:tensorflow:Saving checkpoints for 1200 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.220417.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:24:05
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1200
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:24:18
# INFO:tensorflow:Saving dict for global step 1200: accuracy = 0.9432, global_step = 1200, loss = 0.205675
# Epoch: 12, Validation error: 0.0568, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1200
# INFO:tensorflow:Saving checkpoints for 1201 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.218069, step = 1201
# INFO:tensorflow:Saving checkpoints for 1300 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.222791.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:27:01
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1300
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:27:11
# INFO:tensorflow:Saving dict for global step 1300: accuracy = 0.9513, global_step = 1300, loss = 0.180445
# Epoch: 13, Validation error: 0.0487, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1300
# INFO:tensorflow:Saving checkpoints for 1301 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.184663, step = 1301
# INFO:tensorflow:Saving checkpoints for 1400 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.202359.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:29:37
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1400
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:29:48
# INFO:tensorflow:Saving dict for global step 1400: accuracy = 0.9528, global_step = 1400, loss = 0.17558
# Epoch: 14, Validation error: 0.0472, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1400
# INFO:tensorflow:Saving checkpoints for 1401 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.188683, step = 1401
# INFO:tensorflow:Saving checkpoints for 1500 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.172004.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:32:44
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1500
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:32:56
# INFO:tensorflow:Saving dict for global step 1500: accuracy = 0.9577, global_step = 1500, loss = 0.167937
# Epoch: 15, Validation error: 0.0423, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1500
# INFO:tensorflow:Saving checkpoints for 1501 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.15715, step = 1501
# INFO:tensorflow:Saving checkpoints for 1600 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.180334.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:35:35
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1600
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:35:45
# INFO:tensorflow:Saving dict for global step 1600: accuracy = 0.9575, global_step = 1600, loss = 0.155852
# Epoch: 16, Validation error: 0.0425, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1600
# INFO:tensorflow:Saving checkpoints for 1601 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.172197, step = 1601
# INFO:tensorflow:Saving checkpoints for 1700 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.185282.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:38:06
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1700
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:38:16
# INFO:tensorflow:Saving dict for global step 1700: accuracy = 0.9616, global_step = 1700, loss = 0.14382
# Epoch: 17, Validation error: 0.0384, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1700
# INFO:tensorflow:Saving checkpoints for 1701 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.163087, step = 1701
# INFO:tensorflow:Saving checkpoints for 1800 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.117752.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:41:01
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1800
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:41:12
# INFO:tensorflow:Saving dict for global step 1800: accuracy = 0.9641, global_step = 1800, loss = 0.138094
# Epoch: 18, Validation error: 0.0359, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1800
# INFO:tensorflow:Saving checkpoints for 1801 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.114488, step = 1801
# INFO:tensorflow:Saving checkpoints for 1900 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.147582.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:43:46
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1900
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:43:57
# INFO:tensorflow:Saving dict for global step 1900: accuracy = 0.966, global_step = 1900, loss = 0.129864
# Epoch: 19, Validation error: 0.0340, Learning rate: 0.0100
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-1900
# INFO:tensorflow:Saving checkpoints for 1901 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:loss = 0.174508, step = 1901
# INFO:tensorflow:Saving checkpoints for 2000 into C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.10987.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:46:13
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmpvz46kow9\model.ckpt-2000
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:46:22
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 0.968, global_step = 2000, loss = 0.124915
# Epoch: 20, Validation error: 0.0320, Learning rate: 0.0100
# Duration: 3338.3s
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Hakan\\AppData\\Local\\Temp\\tmphbt5sszj', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001CC0284E828>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 2.29736, step = 1
# INFO:tensorflow:Saving checkpoints for 100 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.88645.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:48:41
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-100
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:48:53
# INFO:tensorflow:Saving dict for global step 100: accuracy = 0.6275, global_step = 100, loss = 1.88313
# Epoch: 1, Validation error: 0.3725, Learning rate: 0.0010
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-100
# INFO:tensorflow:Saving checkpoints for 101 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 1.89121, step = 101
# INFO:tensorflow:Saving checkpoints for 200 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.25956.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:51:27
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-200
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:51:38
# INFO:tensorflow:Saving dict for global step 200: accuracy = 0.7741, global_step = 200, loss = 1.24268
# Epoch: 2, Validation error: 0.2259, Learning rate: 0.0010
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-200
# INFO:tensorflow:Saving checkpoints for 201 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 1.28112, step = 201
# INFO:tensorflow:Saving checkpoints for 300 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.802457.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:54:02
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-300
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:54:13
# INFO:tensorflow:Saving dict for global step 300: accuracy = 0.8255, global_step = 300, loss = 0.782889
# Epoch: 3, Validation error: 0.1745, Learning rate: 0.0010
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-300
# INFO:tensorflow:Saving checkpoints for 301 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 0.839178, step = 301
# INFO:tensorflow:Saving checkpoints for 400 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.602975.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:56:53
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-400
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:57:04
# INFO:tensorflow:Saving dict for global step 400: accuracy = 0.8524, global_step = 400, loss = 0.585927
# Epoch: 4, Validation error: 0.1476, Learning rate: 0.0010
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-400
# INFO:tensorflow:Saving checkpoints for 401 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 0.674377, step = 401
# INFO:tensorflow:Saving checkpoints for 500 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.54628.
# INFO:tensorflow:Starting evaluation at 2017-11-21-23:59:42
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-500
# INFO:tensorflow:Finished evaluation at 2017-11-21-23:59:51
# INFO:tensorflow:Saving dict for global step 500: accuracy = 0.8669, global_step = 500, loss = 0.491396
# Epoch: 5, Validation error: 0.1331, Learning rate: 0.0010
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-500
# INFO:tensorflow:Saving checkpoints for 501 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 0.526012, step = 501
# INFO:tensorflow:Saving checkpoints for 600 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.483599.
# INFO:tensorflow:Starting evaluation at 2017-11-22-00:02:33
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-600
# INFO:tensorflow:Finished evaluation at 2017-11-22-00:02:48
# INFO:tensorflow:Saving dict for global step 600: accuracy = 0.877, global_step = 600, loss = 0.437849
# Epoch: 6, Validation error: 0.1230, Learning rate: 0.0010
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-600
# INFO:tensorflow:Saving checkpoints for 601 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 0.479063, step = 601
# INFO:tensorflow:Saving checkpoints for 700 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.425573.
# INFO:tensorflow:Starting evaluation at 2017-11-22-00:05:48
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-700
# INFO:tensorflow:Finished evaluation at 2017-11-22-00:05:59
# INFO:tensorflow:Saving dict for global step 700: accuracy = 0.886, global_step = 700, loss = 0.404905
# Epoch: 7, Validation error: 0.1140, Learning rate: 0.0010
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-700
# INFO:tensorflow:Saving checkpoints for 701 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 0.460103, step = 701
# INFO:tensorflow:Saving checkpoints for 800 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.47499.
# INFO:tensorflow:Starting evaluation at 2017-11-22-00:08:50
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-800
# INFO:tensorflow:Finished evaluation at 2017-11-22-00:09:03
# INFO:tensorflow:Saving dict for global step 800: accuracy = 0.8896, global_step = 800, loss = 0.382247
# Epoch: 8, Validation error: 0.1104, Learning rate: 0.0010
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-800
# INFO:tensorflow:Saving checkpoints for 801 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 0.42532, step = 801
# INFO:tensorflow:Saving checkpoints for 900 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.427716.
# INFO:tensorflow:Starting evaluation at 2017-11-22-00:11:55
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-900
# INFO:tensorflow:Finished evaluation at 2017-11-22-00:12:07
# INFO:tensorflow:Saving dict for global step 900: accuracy = 0.8937, global_step = 900, loss = 0.366045
# Epoch: 9, Validation error: 0.1063, Learning rate: 0.0010
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-900
# INFO:tensorflow:Saving checkpoints for 901 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 0.396544, step = 901
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.427822.
# INFO:tensorflow:Starting evaluation at 2017-11-22-00:14:47
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-11-22-00:14:59
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.8973, global_step = 1000, loss = 0.354568
# Epoch: 10, Validation error: 0.1027, Learning rate: 0.0010
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-1000
# INFO:tensorflow:Saving checkpoints for 1001 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 0.398445, step = 1001
# INFO:tensorflow:Saving checkpoints for 1100 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.439298.
# INFO:tensorflow:Starting evaluation at 2017-11-22-00:17:24
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-1100
# INFO:tensorflow:Finished evaluation at 2017-11-22-00:17:35
# INFO:tensorflow:Saving dict for global step 1100: accuracy = 0.8989, global_step = 1100, loss = 0.344358
# Epoch: 11, Validation error: 0.1011, Learning rate: 0.0010
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-1100
# INFO:tensorflow:Saving checkpoints for 1101 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 0.406466, step = 1101
# INFO:tensorflow:Saving checkpoints for 1200 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.408436.
# INFO:tensorflow:Starting evaluation at 2017-11-22-00:20:13
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-1200
# INFO:tensorflow:Finished evaluation at 2017-11-22-00:20:26
# INFO:tensorflow:Saving dict for global step 1200: accuracy = 0.9021, global_step = 1200, loss = 0.336945
# Epoch: 12, Validation error: 0.0979, Learning rate: 0.0010
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-1200
# INFO:tensorflow:Saving checkpoints for 1201 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 0.416961, step = 1201
# INFO:tensorflow:Saving checkpoints for 1300 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.38075.
# INFO:tensorflow:Starting evaluation at 2017-11-22-00:23:11
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-1300
# INFO:tensorflow:Finished evaluation at 2017-11-22-00:23:22
# INFO:tensorflow:Saving dict for global step 1300: accuracy = 0.904, global_step = 1300, loss = 0.330712
# Epoch: 13, Validation error: 0.0960, Learning rate: 0.0010
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-1300
# INFO:tensorflow:Saving checkpoints for 1301 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 0.33918, step = 1301
# INFO:tensorflow:Saving checkpoints for 1400 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.343305.
# INFO:tensorflow:Starting evaluation at 2017-11-22-00:26:09
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-1400
# INFO:tensorflow:Finished evaluation at 2017-11-22-00:26:21
# INFO:tensorflow:Saving dict for global step 1400: accuracy = 0.9054, global_step = 1400, loss = 0.326235
# Epoch: 14, Validation error: 0.0946, Learning rate: 0.0010
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-1400
# INFO:tensorflow:Saving checkpoints for 1401 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 0.304294, step = 1401
# INFO:tensorflow:Saving checkpoints for 1500 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.356937.
# INFO:tensorflow:Starting evaluation at 2017-11-22-00:28:59
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-1500
# INFO:tensorflow:Finished evaluation at 2017-11-22-00:29:11
# INFO:tensorflow:Saving dict for global step 1500: accuracy = 0.9078, global_step = 1500, loss = 0.321974
# Epoch: 15, Validation error: 0.0922, Learning rate: 0.0010
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-1500
# INFO:tensorflow:Saving checkpoints for 1501 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 0.342777, step = 1501
# INFO:tensorflow:Saving checkpoints for 1600 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.340948.
# INFO:tensorflow:Starting evaluation at 2017-11-22-00:31:32
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-1600
# INFO:tensorflow:Finished evaluation at 2017-11-22-00:31:42
# INFO:tensorflow:Saving dict for global step 1600: accuracy = 0.9074, global_step = 1600, loss = 0.319002
# Epoch: 16, Validation error: 0.0926, Learning rate: 0.0010
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt-1600
# INFO:tensorflow:Saving checkpoints for 1601 into C:\Users\Hakan\AppData\Local\Temp\tmphbt5sszj\model.ckpt.
# INFO:tensorflow:loss = 0.35528, step = 1601

# %%
# Plot learning curves for different values of the learning rate
learning_fig = plt.figure()
for idx in range(learning_data.shape[0]):
    plt.plot(learning_data[idx,:]*100,LineWidth=2,label='LR: '+str(learning_rates[idx]))
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Validation error (%)')
plt.savefig("Learning_curves.png")

# %%
# Plot parameter nums over filter nums
filter_nums = np.array(filter_nums)
parameter_nums = filter_nums*(3*3+1) + filter_nums*(3*3*filter_nums+1) + 128*(28*28*filter_nums+1)

parameter_num_fig = plt.figure()
plt.scatter(filter_nums,parameter_nums)
plt.xlabel('Number of filters')
plt.ylabel('Number of parameters')
plt.savefig('Num_Parameters_over_Num_Filters.png')

# %%
# Train network with different filter nums and log training time
run_times = np.zeros(len(filter_nums[0:4]))
for idx,filter_num in enumerate(filter_nums[0:4]):
    t0 = time.time()
    train(X_train,y_train,X_valid,y_valid, default_rate, batch_size, max_epochs, filter_num)
    t1 = time.time()
    run_times[idx] = t1-t0
    print('Duration: {:.1f}s'.format(t1-t0))

# %%
# Plot training times over parameter nums
runtime_fig = plt.figure()
plt.scatter(parameter_nums[0:4],run_times)
plt.xlabel('Number of parameters')
plt.ylabel('Training time (s)')
plt.savefig('Runtimes_CPU.png')
